# %%
import numpy as np
import pandas as pd
import pickle
import geopandas as gpd

# %% [markdown]
# Names of STATES and DISTRICTS from NFHS-5
# -----

# %%
with open('../DATA/states.pickle', 'rb') as f:
    # The protocol version used is detected automatically, so we do not
    # have to specify it.
    states = pickle.load(f)
    
with open('../DATA/districts.pickle', 'rb') as f:
    # The protocol version used is detected automatically, so we do not
    # have to specify it.
    districts = pickle.load(f)
    
with open('../DATA/indicators.pickle', 'rb') as f:
    # The protocol version used is detected automatically, so we do not
    # have to specify it.
    indicators = pickle.load(f)

# %%
print('STATES : # DISTRICTS (from NFHS-5 database)')
print('===========================================')
count = 0
idx = 1
for k in np.sort(list(districts.keys())):
    if len(districts[k])==0:
        districts[k] = [k]
    print(idx,':', k,':',len(districts[k]))
    count += len(districts[k])
    idx += 1
    
print(f'Total number of districts = {count}')
# Out:
# STATES : # DISTRICTS (from NFHS-5 database)
# ===========================================
# 1 : Andaman_Nicobar_Islands : 3
# 2 : Andhra_Pradesh : 13
# 3 : Arunachal_Pradesh : 20
# 4 : Assam : 33
# 5 : Bihar : 38
# 6 : Chandigarh : 1
# 7 : Chhattisgarh : 27
# 8 : Dadra_Nagar_Haveli_Daman_Diu : 3
# 9 : Goa : 2
# 10 : Gujarat : 33
# 11 : Haryana : 22
# 12 : Himachal_Pradesh : 12
# 13 : Jammu_Kashmir : 20
# 14 : Jharkhand : 24
# 15 : Karnataka : 30
# 16 : Kerala : 14
# 17 : Ladakh : 2
# 18 : Lakshadweep : 1
# 19 : Madhya_Pradesh : 51
# 20 : Maharashtra : 36
# 21 : Manipur : 9
# 22 : Meghalaya : 11
# 23 : Mizoram : 8
# 24 : NCT_Delhi : 11
# 25 : Nagaland : 11
# 26 : Odisha : 30
# 27 : Puducherry : 4
# 28 : Punjab : 22
# 29 : Rajasthan : 33
# 30 : Sikkim : 4
# 31 : Tamil_Nadu : 32
# 32 : Telangana : 31
# 33 : Tripura : 8
# 34 : Uttar_Pradesh : 75
# 35 : Uttarakhand : 13
# 36 : West_Bengal : 20
# Total number of districts = 707

# %% [markdown]
# Names of STATES and DISTRICTS from district-level shapefiles
# -----

# %%
districts_shp=gpd.read_file("../DATA/DistShapeFiles/output.shp")

# %%
districts_shp.columns.values
# Out:
# array(['objectid', 'statecode', 'statename', 'state_ut', 'distcode',
#        'distname', 'distarea', 'totalpopul', 'totalhh', 'totpopmale',
#        'totpopfema', 'st_areasha', 'st_lengths', 'geometry'], dtype=object)

# %%
np.unique(list(districts_shp['statename']))
# Out:
# array(['Andaman & Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhatisgarh',
#        'Dadra & Nagar Haveli', 'Daman & Diu', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'NCT of Delhi', 'Nagaland',
#        'Orissa', 'Pondicherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype='<U25')

# %%
# Based on above cell, rename states to match names used in NFHS-5
rename_state = {
    'Andaman & Nicobar Islands' : 'Andaman_Nicobar_Islands',
    'Andhra Pradesh' : 'Andhra_Pradesh',
    'Arunachal Pradesh' :  'Arunachal_Pradesh',
    'Chhatisgarh' : 'Chhattisgarh',
    'Dadra & Nagar Haveli' : 'Dadra_Nagar_Haveli_Daman_Diu',
    'Daman & Diu' : 'Dadra_Nagar_Haveli_Daman_Diu',
    'Himachal Pradesh' : 'Himachal_Pradesh',
    'Jammu & Kashmir' : 'Jammu_Kashmir',
    'Madhya Pradesh' : 'Madhya_Pradesh',
    'NCT of Delhi' : 'NCT_Delhi',
    'Tamil Nadu' : 'Tamil_Nadu',
    'Uttar Pradesh' : 'Uttar_Pradesh',
    'West Bengal' : 'West_Bengal',
    'Orissa' : 'Odisha',
    'Pondicherry' : 'Puducherry'
}

# %%
# Rename state names using dictionary rename_state
districts_shp['statename'] = districts_shp['statename'].replace(rename_state)

# %%
# Print district names for each state in shapefile
# Also print if the same district name exists in NFHS-5 database
# Count the number of districts in shapefile that do not match NFHS-5 entries

for st in np.unique(districts_shp['statename']):
    count = 0
    count_false = 0
    for i, j in zip(districts_shp['statename'], districts_shp['distname']):
        if i == st:
           print(i,':', j, ':', j in districts[st])
           count_false += (j not in districts[st])
           count += 1
    print(f'Num districts in shapefile = {count}')
    print(f'Num false = {count_false}')
    print('NFHS-5 districts for ', st, ':', districts[st], len(districts[st]))
    print('\n')
# Out:
# Andaman_Nicobar_Islands : North  & Middle Andaman : False
# Andaman_Nicobar_Islands : South Andaman : True
# Andaman_Nicobar_Islands : Nicobars : False
# Num districts in shapefile = 3
# Num false = 2
# NFHS-5 districts for  Andaman_Nicobar_Islands : ['Nicobar', 'North & Middle Andaman', 'South Andaman'] 3
#
#
# Andhra_Pradesh : Prakasam : True
# Andhra_Pradesh : Krishna : True
# Andhra_Pradesh : Kurnool : True
# Andhra_Pradesh : Guntur : True
# Andhra_Pradesh : Vizianagaram : True
# Andhra_Pradesh : Anantapur : True
# Andhra_Pradesh : West Godavari : True
# Andhra_Pradesh : Kadapa(YSR) : False
# Andhra_Pradesh : East Godavari : True
# Andhra_Pradesh : Visakhapatnam : True
# Andhra_Pradesh : Sri Potti Sriramulu Nellore : True
# Andhra_Pradesh : Chittoor : True
# Andhra_Pradesh : Srikakulam : True
# Num districts in shapefile = 13
# Num false = 1
# NFHS-5 districts for  Andhra_Pradesh : ['Anantapur', 'Chittoor', 'East Godavari', 'Guntur', 'Krishna', 'Kurnool', 'Prakasam', 'Sri Potti Sriramulu Nellore', 'Srikakulam', 'Visakhapatnam', 'Vizianagaram', 'West Godavari', 'Y.S.R.'] 13
#
#
# Arunachal_Pradesh : Lohit : True
# Arunachal_Pradesh : West Siang : True
# Arunachal_Pradesh : Upper Subansiri : True
# Arunachal_Pradesh : Changlang : True
# Arunachal_Pradesh : Tirap : True
# Arunachal_Pradesh : Lower Subansiri : True
# Arunachal_Pradesh : East Kameng : True
# Arunachal_Pradesh : Upper Siang : True
# Arunachal_Pradesh : Anjaw : True
# Arunachal_Pradesh : East Siang : True
# Arunachal_Pradesh : Dibang Valley : True
# Arunachal_Pradesh : Kurung Kumey : True
# Arunachal_Pradesh : West Kameng : True
# Arunachal_Pradesh : Lower Dibang Valley : True
# Arunachal_Pradesh : Tawang : True
# Arunachal_Pradesh : Papum Pare : False
# Num districts in shapefile = 16
# Num false = 1
# NFHS-5 districts for  Arunachal_Pradesh : ['Anjaw', 'Changlang', 'Dibang Valley', 'East Kameng', 'East Siang', 'Kra Daadi', 'Kurung Kumey', 'Lohit', 'Longding', 'Lower Dibang Valley', 'Lower Subansiri', 'Namsai', 'Papumpare', 'Siang', 'Tawang', 'Tirap', 'Upper Siang', 'Upper Subansiri', 'West Kameng', 'West Siang'] 20
#
#
# Assam : Goalpara : True
# Assam : Baksa : True
# Assam : Nagaon : True
# Assam : Nalbari : True
# Assam : Dhubri : True
# Assam : Sivasagar : True
# Assam : Karimganj : True
# Assam : Tinsukia : True
# Assam : Hailakandi : True
# Assam : Chirang : True
# Assam : Cachar : True
# Assam : Darrang : True
# Assam : Kamrup : True
# Assam : Dibrugarh : True
# Assam : Barpeta : True
# Assam : Dhemaji : True
# Assam : Sonitpur : True
# Assam : Udalguri : True
# Assam : Morigaon : True
# Assam : Karbi Anglong : True
# Assam : Lakhimpur : True
# Assam : Golaghat : True
# Assam : Dima Hasao : True
# Assam : Bongaigaon : True
# Assam : Kamrup Metropolitan : True
# Assam : Kokrajhar : True
# Assam : Jorhat : True
# Num districts in shapefile = 27
# Num false = 0
# NFHS-5 districts for  Assam : ['Baksa', 'Barpeta', 'Biswanath', 'Bongaigaon', 'Cachar', 'Charaideo', 'Chirang', 'Darrang', 'Dhemaji', 'Dhubri', 'Dibrugarh', 'Dima Hasao', 'Goalpara', 'Golaghat', 'Hailakandi', 'Hojai', 'Jorhat', 'Kamrup Metropolitan', 'Kamrup', 'Karbi Anglong', 'Karimganj', 'Kokrajhar', 'Lakhimpur', 'Majuli', 'Morigaon', 'Nagaon', 'Nalbari', 'Sivasagar', 'Sonitpur', 'South Salmara Mancachar', 'Tinsukia', 'Udalguri', 'West Karbi Anglong'] 33
#
#
# Bihar : Sheikhpura : True
# Bihar : Jehanabad : True
# Bihar : Saharsa : True
# Bihar : Patna : True
# Bihar : Gopalganj : True
# Bihar : Vaishali : True
# Bihar : Siwan : True
# Bihar : Sheohar : True
# Bihar : Buxar : True
# Bihar : Madhubani : True
# Bihar : Supaul : True
# Bihar : Bhojpur : True
# Bihar : Darbhanga : True
# Bihar : Samastipur : True
# Bihar : Kaimur (Bhabua) : True
# Bihar : Rohtas : True
# Bihar : Khagaria : True
# Bihar : Arwal : True
# Bihar : Bhagalpur : True
# Bihar : Purnia : True
# Bihar : Madhepura : True
# Bihar : Munger : True
# Bihar : Sitamarhi : True
# Bihar : Purba Champaran : True
# Bihar : Lakhisarai : True
# Bihar : Jamui : True
# Bihar : Begusarai : True
# Bihar : Nalanda : True
# Bihar : Katihar : True
# Bihar : Kishanganj : True
# Bihar : Gaya : True
# Bihar : Banka : True
# Bihar : Aurangabad : True
# Bihar : Nawada : True
# Bihar : Araria : True
# Bihar : Pashchim Champaran : True
# Bihar : Muzaffarpur : True
# Bihar : Saran : True
# Num districts in shapefile = 38
# Num false = 0
# NFHS-5 districts for  Bihar : ['Araria', 'Arwal', 'Aurangabad', 'Banka', 'Begusarai', 'Bhagalpur', 'Bhojpur', 'Buxar', 'Darbhanga', 'Gaya', 'Gopalganj', 'Jamui', 'Jehanabad', 'Kaimur (Bhabua)', 'Katihar', 'Khagaria', 'Kishanganj', 'Lakhisarai', 'Madhepura', 'Madhubani', 'Munger', 'Muzaffarpur', 'Nalanda', 'Nawada', 'Pashchim Champaran', 'Patna', 'Purba Champaran', 'Purnia', 'Rohtas', 'Saharsa', 'Samastipur', 'Saran', 'Sheikhpura', 'Sheohar', 'Sitamarhi', 'Siwan', 'Supaul', 'Vaishali'] 38
#
#
# Chandigarh : Chandigarh : True
# Num districts in shapefile = 1
# Num false = 0
# NFHS-5 districts for  Chandigarh : ['Chandigarh'] 1
#
#
# Chhattisgarh : Bemetra : False
# Chhattisgarh : Bastar : True
# Chhattisgarh : Mungeli : True
# Chhattisgarh : Bilaspur : True
# Chhattisgarh : Gariaband : False
# Chhattisgarh : Kabeerdham : True
# Chhattisgarh : Sukma : True
# Chhattisgarh : Uttar Bastar Kanker : True
# Chhattisgarh : Baloda Bazar : True
# Chhattisgarh : Balod : True
# Chhattisgarh : Dakshin Bastar Dantewada : False
# Chhattisgarh : Surguja : True
# Chhattisgarh : Balrampur : True
# Chhattisgarh : Kondagaon : False
# Chhattisgarh : Narayanpur : True
# Chhattisgarh : Durg : True
# Chhattisgarh : Surajpur : True
# Chhattisgarh : Bijapur : True
# Chhattisgarh : Raipur : True
# Chhattisgarh : Koriya : True
# Chhattisgarh : Dhamtari : True
# Chhattisgarh : Korba : True
# Chhattisgarh : Raigarh : True
# Chhattisgarh : Jashpur : True
# Chhattisgarh : Mahasamund : True
# Chhattisgarh : Rajnandgaon : True
# Chhattisgarh : Janjgir-Champa : True
# Num districts in shapefile = 27
# Num false = 4
# NFHS-5 districts for  Chhattisgarh : ['Balod', 'Baloda Bazar', 'Balrampur', 'Bastar', 'Bemetara', 'Bijapur', 'Bilaspur', 'Dantewada', 'Dhamtari', 'Durg', 'Gariyaband', 'Janjgir-Champa', 'Jashpur', 'Kabeerdham', 'Kodagaon', 'Korba', 'Koriya', 'Mahasamund', 'Mungeli', 'Narayanpur', 'Raigarh', 'Raipur', 'Rajnandgaon', 'Sukma', 'Surajpur', 'Surguja', 'Uttar Bastar Kanker'] 27
#
#
# Dadra_Nagar_Haveli_Daman_Diu : Daman : True
# Dadra_Nagar_Haveli_Daman_Diu : Diu : True
# Dadra_Nagar_Haveli_Daman_Diu : Dadra & Nagar Haveli : True
# Num districts in shapefile = 3
# Num false = 0
# NFHS-5 districts for  Dadra_Nagar_Haveli_Daman_Diu : ['Dadra & Nagar Haveli', 'Daman', 'Diu'] 3
#
#
# Goa : North Goa : True
# Goa : South Goa : True
# Num districts in shapefile = 2
# Num false = 0
# NFHS-5 districts for  Goa : ['North Goa', 'South Goa'] 2
#
#
# Gujarat : Sabar Kantha : False
# Gujarat : Banas Kantha : False
# Gujarat : Surendranagar : True
# Gujarat : Anand : True
# Gujarat : Narmada : True
# Gujarat : Amreli : True
# Gujarat : Dohad : False
# Gujarat : Vadodara : True
# Gujarat : Aravali : True
# Gujarat : Bhavnagar : True
# Gujarat : Ahmadabad : False
# Gujarat : Chhota Udaipur : True
# Gujarat : Batod : False
# Gujarat : Rajkot : True
# Gujarat : Kachchh : True
# Gujarat : The Dangs : True
# Gujarat : Mahesana : True
# Gujarat : Patan : True
# Gujarat : Bharuch : True
# Gujarat : Gir Somnath : True
# Gujarat : Junagadh : True
# Gujarat : Devbhumi Dwarka : True
# Gujarat : Navsari : True
# Gujarat : Surat : True
# Gujarat : Jamnagar : True
# Gujarat : Tapi : True
# Gujarat : Kheda : True
# Gujarat : Porbandar : True
# Gujarat : Valsad : True
# Gujarat : Gandhinagar : True
# Gujarat : Mahisagar : True
# Gujarat : Morbi : True
# Gujarat : Panch Mahals : False
# Num districts in shapefile = 33
# Num false = 6
# NFHS-5 districts for  Gujarat : ['Ahmedabad', 'Amreli', 'Anand', 'Aravali', 'Banaskantha', 'Bharuch', 'Bhavnagar', 'Botad', 'Chhota Udaipur', 'Dahod', 'Devbhumi Dwarka', 'Gandhinagar', 'Gir Somnath', 'Jamnagar', 'Junagadh', 'Kachchh', 'Kheda', 'Mahesana', 'Mahisagar', 'Morbi', 'Narmada', 'Navsari', 'Panchmahal', 'Patan', 'Porbandar', 'Rajkot', 'Sabarkantha', 'Surat', 'Surendranagar', 'Tapi', 'The Dangs', 'Vadodara', 'Valsad'] 33
#
#
# Haryana : Mewat : True
# Haryana : Jhajjar : True
# Haryana : Bhiwani : True
# Haryana : Kaithal : True
# Haryana : Sonipat : True
# Haryana : Karnal : True
# Haryana : Kurukshetra : True
# Haryana : Jind : True
# Haryana : Panipat : True
# Haryana : Mahendragarh : True
# Haryana : Fatehabad : True
# Haryana : Faridabad : True
# Haryana : Sirsa : True
# Haryana : Hisar : True
# Haryana : Rewari : True
# Haryana : Rohtak : True
# Haryana : Ambala : True
# Haryana : Gurgaon : True
# Haryana : Yamunanagar : True
# Haryana : Palwal : True
# Haryana : Panchkula : True
# Num districts in shapefile = 21
# Num false = 0
# NFHS-5 districts for  Haryana : ['Ambala', 'Bhiwani', 'Charkhi Dadri', 'Faridabad', 'Fatehabad', 'Gurgaon', 'Hisar', 'Jhajjar', 'Jind', 'Kaithal', 'Karnal', 'Kurukshetra', 'Mahendragarh', 'Mewat', 'Palwal', 'Panchkula', 'Panipat', 'Rewari', 'Rohtak', 'Sirsa', 'Sonipat', 'Yamunanagar'] 22
#
#
# Himachal_Pradesh : Chamba : True
# Himachal_Pradesh : Shimla : True
# Himachal_Pradesh : Bilaspur : True
# Himachal_Pradesh : Kangra : True
# Himachal_Pradesh : Lahul & Spiti : False
# Himachal_Pradesh : Una : True
# Himachal_Pradesh : Solan : True
# Himachal_Pradesh : Sirmaur : True
# Himachal_Pradesh : Kinnaur : True
# Himachal_Pradesh : Mandi : True
# Himachal_Pradesh : Kullu : True
# Himachal_Pradesh : Hamirpur : True
# Num districts in shapefile = 12
# Num false = 1
# NFHS-5 districts for  Himachal_Pradesh : ['Bilaspur', 'Chamba', 'Hamirpur', 'Kangra', 'Kinnaur', 'Kullu', 'Lahul and Spiti', 'Mandi', 'Shimla', 'Sirmaur', 'Solan', 'Una'] 12
#
#
# Jammu_Kashmir : DATA NOT AVAILABLE : False
# Jammu_Kashmir : Anantnag : True
# Jammu_Kashmir : Baramula : True
# Jammu_Kashmir : Kulgam : True
# Jammu_Kashmir : Shupiyan : True
# Jammu_Kashmir : Reasi : True
# Jammu_Kashmir : Rajouri : True
# Jammu_Kashmir : Jammu : True
# Jammu_Kashmir : Srinagar : True
# Jammu_Kashmir : Punch : True
# Jammu_Kashmir : Kupwara : True
# Jammu_Kashmir : Samba : True
# Jammu_Kashmir : Bandipore : True
# Jammu_Kashmir : Kathua : True
# Jammu_Kashmir : Kishtwar : True
# Jammu_Kashmir : Doda : True
# Jammu_Kashmir : Pulwama : True
# Jammu_Kashmir : Ramban : True
# Jammu_Kashmir : Ganderbal : True
# Jammu_Kashmir : Udhampur : True
# Jammu_Kashmir : Badgam : True
# Num districts in shapefile = 21
# Num false = 1
# NFHS-5 districts for  Jammu_Kashmir : ['Anantnag', 'Badgam', 'Bandipore', 'Baramula', 'Doda', 'Ganderbal', 'Jammu', 'Kathua', 'Kishtwar', 'Kulgam', 'Kupwara', 'Pulwama', 'Punch', 'Rajouri', 'Ramban', 'Reasi', 'Samba', 'Shupiyan', 'Srinagar', 'Udhampur'] 20
#
#
# Jharkhand : Jamtara : True
# Jharkhand : Saraikela-Kharsawan : True
# Jharkhand : Simdega : True
# Jharkhand : Latehar : True
# Jharkhand : Khunti : True
# Jharkhand : Pashchimi Singhbhum : True
# Jharkhand : Hazaribagh : True
# Jharkhand : Chatra : True
# Jharkhand : Purbi Singhbhum : True
# Jharkhand : Kodarma : True
# Jharkhand : Giridih : True
# Jharkhand : Bokaro : True
# Jharkhand : Deoghar : True
# Jharkhand : Gumla : True
# Jharkhand : Ramgarh : True
# Jharkhand : Garhwa : True
# Jharkhand : Ranchi : True
# Jharkhand : Pakur : True
# Jharkhand : Lohardaga : True
# Jharkhand : Sahibganj : True
# Jharkhand : Godda : True
# Jharkhand : Palamu : True
# Jharkhand : Dhanbad : True
# Jharkhand : Dumka : True
# Num districts in shapefile = 24
# Num false = 0
# NFHS-5 districts for  Jharkhand : ['Bokaro', 'Chatra', 'Deoghar', 'Dhanbad', 'Dumka', 'Garhwa', 'Giridih', 'Godda', 'Gumla', 'Hazaribagh', 'Jamtara', 'Khunti', 'Kodarma', 'Latehar', 'Lohardaga', 'Pakur', 'Palamu', 'Pashchimi Singhbhum', 'Purbi Singhbhum', 'Ramgarh', 'Ranchi', 'Sahibganj', 'Saraikela-Kharsawan', 'Simdega'] 24
#
#
# Karnataka : Mandya : True
# Karnataka : Mysore : True
# Karnataka : Chikkaballapura : True
# Karnataka : Yadgir : True
# Karnataka : Chikmagalur : True
# Karnataka : Chitradurga : True
# Karnataka : Haveri : True
# Karnataka : Dakshina Kannada : True
# Karnataka : Raichur : True
# Karnataka : Kolar : True
# Karnataka : Bijapur : True
# Karnataka : Uttara Kannada : True
# Karnataka : Davanagere : True
# Karnataka : Dharwad : True
# Karnataka : Bidar : True
# Karnataka : Chamarajanagar : True
# Karnataka : Gulbarga : True
# Karnataka : Gadag : True
# Karnataka : Udupi : True
# Karnataka : Bagalkot : True
# Karnataka : Hassan : True
# Karnataka : Shimoga : True
# Karnataka : Bellary : True
# Karnataka : Kodagu : True
# Karnataka : Bangalore Rural : True
# Karnataka : Tumkur : True
# Karnataka : Belgaum : True
# Karnataka : Koppal : True
# Karnataka : Bangalore : True
# Karnataka : Ramanagara : True
# Num districts in shapefile = 30
# Num false = 0
# NFHS-5 districts for  Karnataka : ['Bagalkot', 'Bangalore Rural', 'Bangalore', 'Belgaum', 'Bellary', 'Bidar', 'Bijapur', 'Chamarajanagar', 'Chikkaballapura', 'Chikmagalur', 'Chitradurga', 'Dakshina Kannada', 'Davanagere', 'Dharwad', 'Gadag', 'Gulbarga', 'Hassan', 'Haveri', 'Kodagu', 'Kolar', 'Koppal', 'Mandya', 'Mysore', 'Raichur', 'Ramanagara', 'Shimoga', 'Tumkur', 'Udupi', 'Uttara Kannada', 'Yadgir'] 30
#
#
# Kerala : Kannur : True
# Kerala : Pathanamthitta : True
# Kerala : Alappuzha : True
# Kerala : Ernakulam : True
# Kerala : Kollam : True
# Kerala : Kasaragod : True
# Kerala : Idukki : True
# Kerala : Kozhikode : True
# Kerala : Kottayam : True
# Kerala : Thrissur : True
# Kerala : Palakkad : True
# Kerala : Thiruvananthapuram : True
# Kerala : Malappuram : True
# Kerala : Wayanad : True
# Num districts in shapefile = 14
# Num false = 0
# NFHS-5 districts for  Kerala : ['Alappuzha', 'Ernakulam', 'Idukki', 'Kannur', 'Kasaragod', 'Kollam', 'Kottayam', 'Kozhikode', 'Malappuram', 'Palakkad', 'Pathanamthitta', 'Thiruvananthapuram', 'Thrissur', 'Wayanad'] 14
#
#
# Ladakh : Kargil : True
# Ladakh : Leh (Ladakh) : True
# Num districts in shapefile = 2
# Num false = 0
# NFHS-5 districts for  Ladakh : ['Kargil', 'Leh (Ladakh)'] 2
#
#
# Lakshadweep : Lakshadweep : True
# Num districts in shapefile = 1
# Num false = 0
# NFHS-5 districts for  Lakshadweep : ['Lakshadweep'] 1
#
#
# Madhya_Pradesh : Bhind : True
# Madhya_Pradesh : Jhabua : True
# Madhya_Pradesh : Seoni : True
# Madhya_Pradesh : Khandwa (East Nimar) : True
# Madhya_Pradesh : Umaria : True
# Madhya_Pradesh : Gwalior : True
# Madhya_Pradesh : Damoh : True
# Madhya_Pradesh : Dhar : True
# Madhya_Pradesh : Katni : True
# Madhya_Pradesh : Sidhi : True
# Madhya_Pradesh : Alirajpur : True
# Madhya_Pradesh : Singrauli : True
# Madhya_Pradesh : Bhopal : True
# Madhya_Pradesh : Rajgarh : True
# Madhya_Pradesh : Mandla : True
# Madhya_Pradesh : Shajapur : True
# Madhya_Pradesh : Shivpuri : True
# Madhya_Pradesh : Datia : True
# Madhya_Pradesh : Shahdol : True
# Madhya_Pradesh : Vidisha : True
# Madhya_Pradesh : Betul : True
# Madhya_Pradesh : Hoshangabad : True
# Madhya_Pradesh : Sehore : True
# Madhya_Pradesh : Jabalpur : True
# Madhya_Pradesh : Narsimhapur : False
# Madhya_Pradesh : Panna : True
# Madhya_Pradesh : Ujjain : True
# Madhya_Pradesh : Rewa : True
# Madhya_Pradesh : Dindori : True
# Madhya_Pradesh : Balaghat : True
# Madhya_Pradesh : Barwani : True
# Madhya_Pradesh : Ashoknagar : True
# Madhya_Pradesh : Raisen : True
# Madhya_Pradesh : Chhindwara : True
# Madhya_Pradesh : Satna : True
# Madhya_Pradesh : Chhatarpur : True
# Madhya_Pradesh : Indore : True
# Madhya_Pradesh : Ratlam : True
# Madhya_Pradesh : Harda : True
# Madhya_Pradesh : Sagar : True
# Madhya_Pradesh : Neemuch : True
# Madhya_Pradesh : Tikamgarh : True
# Madhya_Pradesh : Guna : True
# Madhya_Pradesh : Dewas : True
# Madhya_Pradesh : Mandsaur : True
# Madhya_Pradesh : Khargone (West Nimar) : True
# Madhya_Pradesh : Sheopur : True
# Madhya_Pradesh : Morena : True
# Madhya_Pradesh : Burhanpur : True
# Madhya_Pradesh : Anuppur : True
# Num districts in shapefile = 50
# Num false = 1
# NFHS-5 districts for  Madhya_Pradesh : ['Agar Malwa', 'Alirajpur', 'Anuppur', 'Ashoknagar', 'Balaghat', 'Barwani', 'Betul', 'Bhind', 'Bhopal', 'Burhanpur', 'Chhatarpur', 'Chhindwara', 'Damoh', 'Datia', 'Dewas', 'Dhar', 'Dindori', 'Guna', 'Gwalior', 'Harda', 'Hoshangabad', 'Indore', 'Jabalpur', 'Jhabua', 'Katni', 'Khandwa (East Nimar)', 'Khargone (West Nimar)', 'Mandla', 'Mandsaur', 'Morena', 'Narsinghpur', 'Neemuch', 'Panna', 'Raisen', 'Rajgarh', 'Ratlam', 'Rewa', 'Sagar', 'Satna', 'Sehore', 'Seoni', 'Shahdol', 'Shajapur', 'Sheopur', 'Shivpuri', 'Sidhi', 'Singrauli', 'Tikamgarh', 'Ujjain', 'Umaria', 'Vidisha'] 51
#
#
# Maharashtra : Washim : True
# Maharashtra : Ahmadnagar : False
# Maharashtra : Latur : True
# Maharashtra : Solapur : True
# Maharashtra : Nashik : True
# Maharashtra : Osmanabad : True
# Maharashtra : Sindhudurg : True
# Maharashtra : Kolhapur : True
# Maharashtra : Chandrapur : True
# Maharashtra : Akola : True
# Maharashtra : Parbhani : True
# Maharashtra : Yavatmal : True
# Maharashtra : Nanded : True
# Maharashtra : Dhule : True
# Maharashtra : Satara : True
# Maharashtra : Sangli : True
# Maharashtra : Hingoli : True
# Maharashtra : Pune : True
# Maharashtra : Gondiya : True
# Maharashtra : Amravati : True
# Maharashtra : Nandurbar : True
# Maharashtra : Ratnagiri : True
# Maharashtra : Wardha : True
# Maharashtra : Aurangabad : True
# Maharashtra : Buldana : False
# Maharashtra : Gadchiroli : True
# Maharashtra : Jalgaon : True
# Maharashtra : Raigarh : True
# Maharashtra : Bhandara : True
# Maharashtra : Bid : True
# Maharashtra : Jalna : True
# Maharashtra : Thane : True
# Maharashtra : Palghar : True
# Maharashtra : Mumbai : True
# Maharashtra : Mumbai Suburban : True
# Maharashtra : Nagpur : True
# Num districts in shapefile = 36
# Num false = 2
# NFHS-5 districts for  Maharashtra : ['Ahmednagar', 'Akola', 'Amravati', 'Aurangabad', 'Bhandara', 'Bid', 'Buldhana', 'Chandrapur', 'Dhule', 'Gadchiroli', 'Gondiya', 'Hingoli', 'Jalgaon', 'Jalna', 'Kolhapur', 'Latur', 'Mumbai Suburban', 'Mumbai', 'Nagpur', 'Nanded', 'Nandurbar', 'Nashik', 'Osmanabad', 'Palghar', 'Parbhani', 'Pune', 'Raigarh', 'Ratnagiri', 'Sangli', 'Satara', 'Sindhudurg', 'Solapur', 'Thane', 'Wardha', 'Washim', 'Yavatmal'] 36
#
#
# Manipur : Tamenglong : True
# Manipur : Chandel : True
# Manipur : Ukhrul : True
# Manipur : Bishnupur : True
# Manipur : Churachandpur : True
# Manipur : Thoubal : False
# Manipur : Imphal East : True
# Manipur : Senapati : True
# Manipur : Imphal West : True
# Num districts in shapefile = 9
# Num false = 1
# NFHS-5 districts for  Manipur : ['Bishnupur', 'Chandel', 'Churachandpur', 'Imphal East', 'Imphal West', 'Senapati', 'Tamenglong', 'Toubal', 'Ukhrul'] 9
#
#
# Meghalaya : South Garo Hills : True
# Meghalaya : Ribhoi : True
# Meghalaya : East Khasi Hills : True
# Meghalaya : West Khasi Hills : True
# Meghalaya : South West Khasi Hills : True
# Meghalaya : West Garo Hills : True
# Meghalaya : West Jaintia Hills : True
# Meghalaya : East Garo Hills : True
# Meghalaya : North Garo Hills : True
# Meghalaya : South West Garo Hills : True
# Meghalaya : East Jaintia Hills : True
# Num districts in shapefile = 11
# Num false = 0
# NFHS-5 districts for  Meghalaya : ['East Garo Hills', 'East Jaintia Hills', 'East Khasi Hills', 'North Garo Hills', 'Ribhoi', 'South Garo Hills', 'South West Garo Hills', 'South West Khasi Hills', 'West Garo Hills', 'West Jaintia Hills', 'West Khasi Hills'] 11
#
#
# Mizoram : Mamit : True
# Mizoram : Lunglei : True
# Mizoram : Kolasib : True
# Mizoram : Lawngtlai : True
# Mizoram : Saiha : True
# Mizoram : Champhai : True
# Mizoram : Serchhip : True
# Mizoram : Aizawl : True
# Num districts in shapefile = 8
# Num false = 0
# NFHS-5 districts for  Mizoram : ['Aizawl', 'Champhai', 'Kolasib', 'Lawngtlai', 'Lunglei', 'Mamit', 'Saiha', 'Serchhip'] 8
#
#
# NCT_Delhi : West : True
# NCT_Delhi : New Delhi : True
# NCT_Delhi : East : True
# NCT_Delhi : South : True
# NCT_Delhi : North West : True
# NCT_Delhi : South West : True
# NCT_Delhi : Central : True
# NCT_Delhi : North East : True
# NCT_Delhi : North : True
# Num districts in shapefile = 9
# Num false = 0
# NFHS-5 districts for  NCT_Delhi : ['Central', 'East', 'New Delhi', 'North', 'North East', 'North West', 'Shahdara', 'South', 'South East', 'South West', 'West'] 11
#
#
# Nagaland : Kohima : True
# Nagaland : Wokha : True
# Nagaland : Zunheboto : True
# Nagaland : Kiphire : True
# Nagaland : Dimapur : True
# Nagaland : Peren : True
# Nagaland : Mon : True
# Nagaland : Tuensang : True
# Nagaland : Mokokchung : True
# Nagaland : Longleng : True
# Nagaland : Phek : True
# Num districts in shapefile = 11
# Num false = 0
# NFHS-5 districts for  Nagaland : ['Dimapur', 'Kiphire', 'Kohima', 'Longleng', 'Mokokchung', 'Mon', 'Peren', 'Phek', 'Tuensang', 'Wokha', 'Zunheboto'] 11
#
#
# Odisha : Anugul : True
# Odisha : Koraput : True
# Odisha : Nabarangapur : True
# Odisha : Bargarh : True
# Odisha : Balangir : True
# Odisha : Subarnapur : True
# Odisha : Puri : True
# Odisha : Debagarh : True
# Odisha : Jagatsinghapur : True
# Odisha : Kandhamal : True
# Odisha : Khordha : True
# Odisha : Mayurbhanj : True
# Odisha : Malkangiri : True
# Odisha : Baleshwar : True
# Odisha : Sambalpur : True
# Odisha : Gajapati : True
# Odisha : Dhenkanal : True
# Odisha : Nayagarh : True
# Odisha : Cuttack : True
# Odisha : Jajapur : True
# Odisha : Kalahandi : True
# Odisha : Baudh : True
# Odisha : Kendrapara : True
# Odisha : Kendujhar : True
# Odisha : Ganjam : True
# Odisha : Sundargarh : True
# Odisha : Bhadrak : True
# Odisha : Nuapada : True
# Odisha : Rayagada : True
# Odisha : Jharsuguda : True
# Num districts in shapefile = 30
# Num false = 0
# NFHS-5 districts for  Odisha : ['Anugul', 'Balangir', 'Baleshwar', 'Bargarh', 'Baudh', 'Bhadrak', 'Cuttack', 'Debagarh', 'Dhenkanal', 'Gajapati', 'Ganjam', 'Jagatsinghapur', 'Jajapur', 'Jharsuguda', 'Kalahandi', 'Kandhamal', 'Kendrapara', 'Kendujhar', 'Khordha', 'Koraput', 'Malkangiri', 'Mayurbhanj', 'Nabarangapur', 'Nayagarh', 'Nuapada', 'Puri', 'Rayagada', 'Sambalpur', 'Subarnapur', 'Sundargarh'] 30
#
#
# Puducherry : Yanam : True
# Puducherry : Karaikal : True
# Puducherry : Puducherry : True
# Puducherry : Mahe : True
# Num districts in shapefile = 4
# Num false = 0
# NFHS-5 districts for  Puducherry : ['Karaikal', 'Mahe', 'Puducherry', 'Yanam'] 4
#
#
# Punjab : Shahid Bhagat Singh Nagar : False
# Punjab : Patiala : True
# Punjab : Tarn Taran : True
# Punjab : Kapurthala : True
# Punjab : Fatehgarh Sahib : True
# Punjab : Sangrur : True
# Punjab : Pathankot : True
# Punjab : Gurdaspur : False
# Punjab : Mansa : True
# Punjab : Amritsar : True
# Punjab : Faridkot : True
# Punjab : Ludhiana : True
# Punjab : Bathinda : True
# Punjab : Jalandhar : True
# Punjab : Moga : True
# Punjab : Hoshiarpur : True
# Punjab : Muktsar : True
# Punjab : Rupnagar : True
# Punjab : Firozpur : True
# Punjab : Fazilka : True
# Punjab : Barnala : True
# Punjab : Sahibzada Ajit Singh Nagar : True
# Num districts in shapefile = 22
# Num false = 2
# NFHS-5 districts for  Punjab : ['Amritsar', 'Barnala', 'Bathinda', 'Faridkot', 'Fatehgarh Sahib', 'Fazilka', 'Firozpur', 'Gurudaspur', 'Hoshiarpur', 'Jalandhar', 'Kapurthala', 'Ludhiana', 'Mansa', 'Moga', 'Muktsar', 'Pathankot', 'Patiala', 'Rupnagar', 'Sahibzada Ajit Singh Nagar', 'Sangrur', 'SBS Nagar', 'Tarn Taran'] 22
#
#
# Rajasthan : Jhunjhunun : True
# Rajasthan : Jaisalmer : True
# Rajasthan : Sikar : True
# Rajasthan : Hanumangarh : True
# Rajasthan : Nagaur : True
# Rajasthan : Barmer : True
# Rajasthan : Ganganagar : True
# Rajasthan : Jodhpur : True
# Rajasthan : Churu : True
# Rajasthan : Bikaner : True
# Rajasthan : Pratapgarh : True
# Rajasthan : Pali : True
# Rajasthan : Rajsamand : True
# Rajasthan : Ajmer : True
# Rajasthan : Bharatpur : True
# Rajasthan : Dungarpur : True
# Rajasthan : Chittaurgarh : True
# Rajasthan : Udaipur : True
# Rajasthan : Jalor : True
# Rajasthan : Dausa : True
# Rajasthan : Sirohi : True
# Rajasthan : Bhilwara : True
# Rajasthan : Tonk : True
# Rajasthan : Bundi : True
# Rajasthan : Jaipur : True
# Rajasthan : Kota : True
# Rajasthan : Banswara : True
# Rajasthan : Jhalawar : True
# Rajasthan : Alwar : True
# Rajasthan : Baran : True
# Rajasthan : Karauli : True
# Rajasthan : Dhaulpur : True
# Rajasthan : Sawai Madhopur : True
# Num districts in shapefile = 33
# Num false = 0
# NFHS-5 districts for  Rajasthan : ['Ajmer', 'Alwar', 'Banswara', 'Baran', 'Barmer', 'Bharatpur', 'Bhilwara', 'Bikaner', 'Bundi', 'Chittaurgarh', 'Churu', 'Dausa', 'Dhaulpur', 'Dungarpur', 'Ganganagar', 'Hanumangarh', 'Jaipur', 'Jaisalmer', 'Jalor', 'Jhalawar', 'Jhunjhunun', 'Jodhpur', 'Karauli', 'Kota', 'Nagaur', 'Pali', 'Pratapgarh', 'Rajsamand', 'Sawai Madhopur', 'Sikar', 'Sirohi', 'Tonk', 'Udaipur'] 33
#
#
# Sikkim : North District : True
# Sikkim : East District : True
# Sikkim : South District : True
# Sikkim : West District : True
# Num districts in shapefile = 4
# Num false = 0
# NFHS-5 districts for  Sikkim : ['East District', 'North District', 'South District', 'West District'] 4
#
#
# Tamil_Nadu : Cuddalore : True
# Tamil_Nadu : Pudukkottai : True
# Tamil_Nadu : Vellore : True
# Tamil_Nadu : Krishnagiri : True
# Tamil_Nadu : Erode : True
# Tamil_Nadu : Coimbatore : True
# Tamil_Nadu : Sivaganga : True
# Tamil_Nadu : Thanjavur : True
# Tamil_Nadu : Tiruvannamalai : True
# Tamil_Nadu : Ramanathapuram : True
# Tamil_Nadu : Tirunelveli : True
# Tamil_Nadu : Virudhunagar : True
# Tamil_Nadu : Thiruvarur : True
# Tamil_Nadu : Thiruvallur : True
# Tamil_Nadu : Tiruchirappalli : True
# Tamil_Nadu : Tiruppur : True
# Tamil_Nadu : Madurai : True
# Tamil_Nadu : Karur : True
# Tamil_Nadu : Dharmapuri : True
# Tamil_Nadu : Namakkal : True
# Tamil_Nadu : Ariyalur : True
# Tamil_Nadu : Theni : True
# Tamil_Nadu : Salem : True
# Tamil_Nadu : Perambalur : True
# Tamil_Nadu : Dindigul : True
# Tamil_Nadu : Chennai : True
# Tamil_Nadu : Nagapattinam : True
# Tamil_Nadu : Viluppuram : True
# Tamil_Nadu : Kancheepuram : True
# Tamil_Nadu : Kanniyakumari : True
# Tamil_Nadu : Thoothukkudi : True
# Tamil_Nadu : The Nilgiris : True
# Num districts in shapefile = 32
# Num false = 0
# NFHS-5 districts for  Tamil_Nadu : ['Ariyalur', 'Chennai', 'Coimbatore', 'Cuddalore', 'Dharmapuri', 'Dindigul', 'Erode', 'Kancheepuram', 'Kanniyakumari', 'Karur', 'Krishnagiri', 'Madurai', 'Nagapattinam', 'Namakkal', 'Perambalur', 'Pudukkottai', 'Ramanathapuram', 'Salem', 'Sivaganga', 'Thanjavur', 'The Nilgiris', 'Theni', 'Thiruvallur', 'Thiruvarur', 'Thoothukkudi', 'Tiruchirappalli', 'Tirunelveli', 'Tiruppur', 'Tiruvannamalai', 'Vellore', 'Viluppuram', 'Virudhunagar'] 32
#
#
# Telangana : Warangal (R) : False
# Telangana : Jangaon : False
# Telangana : Mancherial : True
# Telangana : Bhadradri : False
# Telangana : Hydrabad : False
# Telangana : Karimnagar : True
# Telangana : Nizamabad : True
# Telangana : Medak : True
# Telangana : Rangareddy : False
# Telangana : Nalgonda : True
# Telangana : Nagarkurnool : True
# Telangana : Adilabad : True
# Telangana : Komaram Bheem : False
# Telangana : Nirmal : True
# Telangana : Jagtial : False
# Telangana : Kamareddy : True
# Telangana : Warangal (U) : False
# Telangana : Jayashankar : False
# Telangana : Peddapalli : True
# Telangana : Rajanna Sircilla : True
# Telangana : Sangareddy : True
# Telangana : Siddipet : True
# Telangana : Mahabubabad : True
# Telangana : Khammam : True
# Telangana : Suryapet : True
# Telangana : Jogulamba : False
# Telangana : Yadadri : False
# Telangana : Medchal : False
# Telangana : Wanaparthy : True
# Telangana : Vikarabad : True
# Telangana : Mahabubnagar : True
# Num districts in shapefile = 31
# Num false = 12
# NFHS-5 districts for  Telangana : ['Adilabad', 'Bhadradri Kothagudem', 'Hyderabad', 'Jagitial', 'Jangoan', 'Jayashankar Bhupalapally', 'Jogulamba Gadwal', 'Kamareddy', 'Karimnagar', 'Khammam', 'Komaram Bheem Asifabad', 'Mahabubabad', 'Mahabubnagar', 'Mancherial', 'Medak', 'Medchal-Malkajgiri', 'Nagarkurnool', 'Nalgonda', 'Nirmal', 'Nizamabad', 'Peddapalli', 'Rajanna Sircilla', 'Ranga Reddy', 'Sangareddy', 'Siddipet', 'Suryapet', 'Vikarabad', 'Wanaparthy', 'Warangal Rural', 'Warangal Urban', 'Yadadri Bhuvanagiri'] 31
#
#
# Tripura : West Tripura : True
# Tripura : Dhalai : True
# Tripura : Unokoti : False
# Tripura : North Tripura : True
# Tripura : Gomati : True
# Tripura : South Tripura : True
# Tripura : Khowai : True
# Tripura : Sipahijula : False
# Num districts in shapefile = 8
# Num false = 2
# NFHS-5 districts for  Tripura : ['Dhalai', 'Gomati', 'Khowai', 'North Tripura', 'Sepahijala', 'South Tripura', 'Unakoti', 'West Tripura'] 8
#
#
# Uttar_Pradesh : Ambedkar Nagar : True
# Uttar_Pradesh : Ballia : True
# Uttar_Pradesh : Kanpur Nagar : True
# Uttar_Pradesh : Sant Ravidas Nagar (Bhadohi) : True
# Uttar_Pradesh : Siddharthnagar : True
# Uttar_Pradesh : Sant Kabir Nagar : False
# Uttar_Pradesh : Varanasi : True
# Uttar_Pradesh : Bara Banki : False
# Uttar_Pradesh : Mahoba : True
# Uttar_Pradesh : Mahrajganj : False
# Uttar_Pradesh : Mirzapur : True
# Uttar_Pradesh : Kushinagar : True
# Uttar_Pradesh : Deoria : True
# Uttar_Pradesh : Unnao : True
# Uttar_Pradesh : Fatehpur : True
# Uttar_Pradesh : Mau : True
# Uttar_Pradesh : Rae Bareli : True
# Uttar_Pradesh : Amethi : True
# Uttar_Pradesh : Ghaziabad : True
# Uttar_Pradesh : Muzaffarnagar : True
# Uttar_Pradesh : Gautam Buddha Nagar : True
# Uttar_Pradesh : Saharanpur : True
# Uttar_Pradesh : Etawah : True
# Uttar_Pradesh : Agra : True
# Uttar_Pradesh : Chandauli : True
# Uttar_Pradesh : Jhansi : True
# Uttar_Pradesh : Banda : True
# Uttar_Pradesh : Sonbhadra : True
# Uttar_Pradesh : Lalitpur : True
# Uttar_Pradesh : Ghazipur : True
# Uttar_Pradesh : Moradabad : True
# Uttar_Pradesh : Sambhal : True
# Uttar_Pradesh : Budaun : True
# Uttar_Pradesh : Kanshiram Nagar : True
# Uttar_Pradesh : Bahraich : True
# Uttar_Pradesh : Hapur : True
# Uttar_Pradesh : Sitapur : True
# Uttar_Pradesh : Samli : False
# Uttar_Pradesh : Shrawasti : False
# Uttar_Pradesh : Mathura : True
# Uttar_Pradesh : Etah : True
# Uttar_Pradesh : Hardoi : True
# Uttar_Pradesh : Balrampur : True
# Uttar_Pradesh : Mahamaya Nagar : True
# Uttar_Pradesh : Shahjahanpur : True
# Uttar_Pradesh : Farrukhabad : True
# Uttar_Pradesh : Kannauj : True
# Uttar_Pradesh : Pilibhit : True
# Uttar_Pradesh : Mainpuri : True
# Uttar_Pradesh : Jyotiba Phule Nagar : True
# Uttar_Pradesh : Firozabad : True
# Uttar_Pradesh : Sultanpur : True
# Uttar_Pradesh : Chitrakoot : True
# Uttar_Pradesh : Basti : True
# Uttar_Pradesh : Gorakhpur : True
# Uttar_Pradesh : Lucknow : True
# Uttar_Pradesh : Azamgarh : True
# Uttar_Pradesh : Faizabad : True
# Uttar_Pradesh : Meerut : True
# Uttar_Pradesh : Aligarh : True
# Uttar_Pradesh : Bulandshahr : True
# Uttar_Pradesh : Bijnor : True
# Uttar_Pradesh : Baghpat : True
# Uttar_Pradesh : Kheri : True
# Uttar_Pradesh : Rampur : True
# Uttar_Pradesh : Bareilly : True
# Uttar_Pradesh : Kaushambi : True
# Uttar_Pradesh : Jalaun : True
# Uttar_Pradesh : Auraiya : True
# Uttar_Pradesh : Pratapgarh : True
# Uttar_Pradesh : Hamirpur : True
# Uttar_Pradesh : Gonda : True
# Uttar_Pradesh : Kanpur Dehat : True
# Uttar_Pradesh : Jaunpur : True
# Uttar_Pradesh : Allahabad : False
# Num districts in shapefile = 75
# Num false = 6
# NFHS-5 districts for  Uttar_Pradesh : ['Agra', 'Aligarh', 'Ambedkar Nagar', 'Amethi', 'Auraiya', 'Azamgarh', 'Baghpat', 'Bahraich', 'Ballia', 'Balrampur', 'Banda', 'Barabanki', 'Bareilly', 'Basti', 'Bijnor', 'Budaun', 'Bulandshahr', 'Chandauli', 'Chitrakoot', 'Deoria', 'Etah', 'Etawah', 'Faizabad', 'Farrukhabad', 'Fatehpur', 'Firozabad', 'Gautam Buddha Nagar', 'Ghaziabad', 'Ghazipur', 'Gonda', 'Gorakhpur', 'Hamirpur', 'Hapur', 'Hardoi', 'Jalaun', 'Jaunpur', 'Jhansi', 'Jyotiba Phule Nagar', 'Kannauj', 'Kanpur Dehat', 'Kanpur Nagar', 'Kanshiram Nagar', 'Kaushambi', 'Kheri', 'Kushinagar', 'Lalitpur', 'Lucknow', 'Mahamaya Nagar', 'Maharajganj', 'Mahoba', 'Mainpuri', 'Mathura', 'Mau', 'Meerut', 'Mirzapur', 'Moradabad', 'Muzaffarnagar', 'Pilibhit', 'Pratapgarh', 'Prayagraj', 'Rae Bareli', 'Rampur', 'Saharanpur', 'Sambhal', 'Sant Kabeer Nagar', 'Sant Ravidas Nagar (Bhadohi)', 'Shahjahanpur', 'Shamli', 'Shravasti', 'Siddharthnagar', 'Sitapur', 'Sonbhadra', 'Sultanpur', 'Unnao', 'Varanasi'] 75
#
#
# Uttarakhand : Nainital : True
# Uttarakhand : Dehradun : True
# Uttarakhand : Almora : True
# Uttarakhand : Champawat : True
# Uttarakhand : Uttarkashi : True
# Uttarakhand : Garhwal : False
# Uttarakhand : Hardwar : False
# Uttarakhand : Rudraprayag : True
# Uttarakhand : Tehri Garhwal : True
# Uttarakhand : Bageshwar : True
# Uttarakhand : Pithoragarh : True
# Uttarakhand : Chamoli : True
# Uttarakhand : Udham Singh Nagar : False
# Num districts in shapefile = 13
# Num false = 3
# NFHS-5 districts for  Uttarakhand : ['Almora', 'Bageshwar', 'Chamoli', 'Champawat', 'Dehradun', 'Haridwar', 'Nainital', 'Pauri Garhwal', 'Pithoragarh', 'Rudraprayag', 'Tehri Garhwal', 'Udam Singh Nagar', 'Uttarkashi'] 13
#
#
# West_Bengal : Hugli : True
# West_Bengal : Nadia : True
# West_Bengal : Dakshin Dinajpur : True
# West_Bengal : Murshidabad : True
# West_Bengal : Barddhaman : False
# West_Bengal : Bankura : True
# West_Bengal : Puruliya : True
# West_Bengal : Koch Bihar : True
# West_Bengal : Paschim Medinipur : True
# West_Bengal : Kolkata : True
# West_Bengal : Maldah : True
# West_Bengal : South Twenty Four Parganas : True
# West_Bengal : Darjiling : False
# West_Bengal : Jalpaiguri : True
# West_Bengal : Uttar Dinajpur : True
# West_Bengal : Purba Medinipur : True
# West_Bengal : Haora : True
# West_Bengal : North Twenty Four Parganas : True
# West_Bengal : Birbhum : True
# Num districts in shapefile = 19
# Num false = 2
# NFHS-5 districts for  West_Bengal : ['Bankura', 'Birbhum', 'Dakshin Dinajpur', 'Darjeeling', 'Haora', 'Hugli', 'Jalpaiguri', 'Koch Bihar', 'Kolkata', 'Maldah', 'Murshidabad', 'Nadia', 'North Twenty Four Parganas', 'Paschim Barddhaman', 'Paschim Medinipur', 'Purba Barddhaman', 'Purba Medinipur', 'Puruliya', 'South Twenty Four Parganas', 'Uttar Dinajpur'] 20

# %%
# Based on output of above cell, correct district names in shapefile
correct_distnames = {
    'Kadapa(YSR)' : 'Y.S.R.',                 # AP
    'Papum Pare' : 'Papumpare',               # AR
    'Bemetra' : 'Bemetara',                   # CT
    'Gariaband' : 'Gariyaband',               # CT
    'Dakshin Bastar Dantewada' : 'Dantewada', # CT: same according to Wikipedia
    'Kondagaon' : 'Kodagaon',                 # CT
    'Sabar Kantha' : 'Sabarkantha',           # GJ
    'Banas Kantha' : 'Banaskantha',           # GJ
    'Dohad' : 'Dahod',                        # GJ
    'Ahmadabad' : 'Ahmedabad',                # GJ
    'Batod' : 'Botad',                        # GJ
    'Panch Mahals' : 'Panchmahal',            # GJ
    'Lahul & Spiti' : 'Lahul and Spiti',      # HP
    'Narsimhapur' : 'Narsinghpur',            # MP
    'Ahmadnagar' : 'Ahmednagar',              # MH
    'Buldana' : 'Buldhana',                   # MH
    'Thoubal' : 'Toubal',                     # Manipur
    'Shahid Bhagat Singh Nagar' : 'SBS Nagar', # PJ
    'Gurdaspur' : 'Gurudaspur',               # PJ
    'Warangal (R)' : 'Warangal Rural',        # TG
    'Jangaon' : 'Jangoan',                    # TG
    'Bhadradri' : 'Bhadradri Kothagudem',     # TG
    'Hydrabad' : 'Hyderabad',                 # TG
    'Rangareddy' : 'Ranga Reddy',             # TG
    'Komaram Bheem' : 'Komaram Bheem Asifabad', # TG
    'Jagtial' : 'Jagitial',                   # TG
    'Warangal (U)' : 'Warangal Urban',        # TG
    'Jayashankar' : 'Jayashankar Bhupalapally', # TG
    'Jogulamba' : 'Jogulamba Gadwal',         # TG 
    'Yadadri' : 'Yadadri Bhuvanagiri',        # TG
    'Medchal' : 'Medchal-Malkajgiri',         # TG
    'Unokoti' : 'Unakoti',                    # TR
    'Sipahijula' : 'Sepahijala',              # TR 
    'Sant Kabir Nagar' : 'Sant Kabeer Nagar', # UP
    'Bara Banki' : 'Barabanki',               # UP
    'Mahrajganj' : 'Maharajganj',             # UP
    'Samli' : 'Shamli',                       # UP
    'Shrawasti' : 'Shravasti',                # UP
    'Allahabad' : 'Prayagraj',                # UP
    'Garhwal' : 'Pauri Garhwal',              # UT
    'Hardwar' : 'Haridwar',                   # UT
    'Udham Singh Nagar' : 'Udam Singh Nagar', # UT
    #'Barddhaman' : 'Barddhaman',             # WB: Barddhaman in shapefile is split into 'Purba Barddhaman' and 'Paschim Barddhaman' in NFHS-5
    'Darjiling' : 'Darjeeling',               # WB
    'North  & Middle Andaman' : 'North & Middle Andaman', #AN
    'Nicobars' : 'Nicobar'                    #AN
}

# %%
districts_shp['distname'] = districts_shp['distname'].replace(correct_distnames)

# %%
D_shp = {}
for i, j in zip(districts_shp['statename'], districts_shp['distname']):
    #print(i, j)
    if i in D_shp.keys():
        D_shp[i].append(j)
    else:
        D_shp[i] = [j]

count = 0
idx = 1
srn = 'No.'
state = 'State'
dcount_nfhs5 = '# districts (from NFHS5)'
dcount_shp = '# districts (from shp)'
print(f'{srn:>4} | {state:>29} | {dcount_shp:>24} | {dcount_nfhs5:>24} | diff')
print('='*99)
for k in np.sort(list(D_shp.keys())):
    if len(D_shp[k])==0:
        D_shp[k] = [k]
    diff = len(districts[k]) - len(D_shp[k])
    print(f'{idx:>4} | {k:>29} | {len(D_shp[k]):>24} | {len(districts[k]):>24} | {diff:>3}')
    count += len(D_shp[k])
    idx += 1
    
print(f'Total number of districts = {count}')
# Out:
#  No. |                         State |   # districts (from shp) | # districts (from NFHS5) | diff
# ===================================================================================================
#    1 |       Andaman_Nicobar_Islands |                        3 |                        3 |   0
#    2 |                Andhra_Pradesh |                       13 |                       13 |   0
#    3 |             Arunachal_Pradesh |                       16 |                       20 |   4
#    4 |                         Assam |                       27 |                       33 |   6
#    5 |                         Bihar |                       38 |                       38 |   0
#    6 |                    Chandigarh |                        1 |                        1 |   0
#    7 |                  Chhattisgarh |                       27 |                       27 |   0
#    8 |  Dadra_Nagar_Haveli_Daman_Diu |                        3 |                        3 |   0
#    9 |                           Goa |                        2 |                        2 |   0
#   10 |                       Gujarat |                       33 |                       33 |   0
#   11 |                       Haryana |                       21 |                       22 |   1
#   12 |              Himachal_Pradesh |                       12 |                       12 |   0
#   13 |                 Jammu_Kashmir |                       21 |                       20 |  -1
#   14 |                     Jharkhand |                       24 |                       24 |   0
#   15 |                     Karnataka |                       30 |                       30 |   0
#   16 |                        Kerala |                       14 |                       14 |   0
#   17 |                        Ladakh |                        2 |                        2 |   0
#   18 |                   Lakshadweep |                        1 |                        1 |   0
#   19 |                Madhya_Pradesh |                       50 |                       51 |   1
#   20 |                   Maharashtra |                       36 |                       36 |   0
#   21 |                       Manipur |                        9 |                        9 |   0
#   22 |                     Meghalaya |                       11 |                       11 |   0
#   23 |                       Mizoram |                        8 |                        8 |   0
#   24 |                     NCT_Delhi |                        9 |                       11 |   2
#   25 |                      Nagaland |                       11 |                       11 |   0
#   26 |                        Odisha |                       30 |                       30 |   0
#   27 |                    Puducherry |                        4 |                        4 |   0
#   28 |                        Punjab |                       22 |                       22 |   0
#   29 |                     Rajasthan |                       33 |                       33 |   0
#   30 |                        Sikkim |                        4 |                        4 |   0
#   31 |                    Tamil_Nadu |                       32 |                       32 |   0
#   32 |                     Telangana |                       31 |                       31 |   0
#   33 |                       Tripura |                        8 |                        8 |   0
#   34 |                 Uttar_Pradesh |                       75 |                       75 |   0
#   35 |                   Uttarakhand |                       13 |                       13 |   0
#   36 |                   West_Bengal |                       19 |                       20 |   1
# Total number of districts = 693

# %%
districts_shp['statedist'] = districts_shp['distname']+districts_shp['statename']

# %%
districts_shp.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 693 entries, 0 to 692
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   objectid    693 non-null    int64
#  1   statecode   693 non-null    object
#  2   statename   693 non-null    object
#  3   state_ut    693 non-null    object
#  4   distcode    693 non-null    object
#  5   distname    693 non-null    object
#  6   distarea    629 non-null    float64
#  7   totalpopul  660 non-null    float64
#  8   totalhh     660 non-null    float64
#  9   totpopmale  660 non-null    float64
#  10  totpopfema  660 non-null    float64
#  11  st_areasha  693 non-null    float64
#  12  st_lengths  693 non-null    float64
#  13  geometry    693 non-null    geometry
#  14  statedist   693 non-null    object
# dtypes: float64(7), geometry(1), int64(1), object(6)
# memory usage: 81.3+ KB

# %% [markdown]
# ## Merge a DataFrame 'NFHS-5_imputed' into GeoDataFrame 'districts' on shared variable 'distname'

# %%
df_nfhs5 = pd.read_csv('../DATA/NFHS5_imputed.csv', index_col = 0)
df_nfhs5
# Out:
#               State       District  Q1_NFHS5  Q2_NFHS5  Q3_NFHS5  Q4_NFHS5  \
# 0    Andhra_Pradesh      Anantapur      59.5      24.3    1047.0     881.0
# 1    Andhra_Pradesh       Chittoor      65.6      22.6    1024.0    1019.0
# 2    Andhra_Pradesh  East Godavari      75.4      20.5     995.0     882.0
# 3    Andhra_Pradesh         Guntur      64.9      22.4    1055.0     941.0
# 4    Andhra_Pradesh        Krishna      74.0      20.4    1064.0    1139.0
# ..              ...            ...       ...       ...       ...       ...
# 700          Ladakh   Leh (Ladakh)      66.3      21.0     967.0     949.0
# 701      Puducherry       Karaikal      86.3      21.9    1132.0     884.0
# 702      Puducherry           Mahe      99.2      16.8    1164.0    1202.0
# 703      Puducherry     Puducherry      83.8      20.1    1106.0     963.0
# 704      Puducherry          Yanam      80.9      21.8    1089.0    1154.0
#
#      Q5_NFHS5  Q6_NFHS5  Q7_NFHS5  Q8_NFHS5  ...  TF_Q95  TF_Q96  TF_Q97  \
# 0        94.3      87.2      99.6      98.8  ...     YES     YES     YES
# 1        94.7      74.3      99.7      98.5  ...     YES     YES     YES
# 2        93.0      68.2      98.8      97.9  ...     YES     YES     YES
# 3        92.3      82.5      99.2      99.3  ...     YES     YES     YES
# 4        96.4      86.3      99.6      94.4  ...     YES     YES     YES
# ..        ...       ...       ...       ...  ...     ...     ...     ...
# 700      98.7      77.7      99.8      87.1  ...     YES     YES     YES
# 701      99.1      95.9      99.6      99.9  ...     YES     YES     YES
# 702      99.4      96.8      99.7      98.0  ...     YES     YES     YES
# 703      99.6      91.3     100.0     100.0  ...     YES     YES     YES
# 704      96.0      94.7      99.8     100.0  ...     YES     YES     YES
#
#      TF_Q98  TF_Q99  TF_Q100  TF_Q101  TF_Q102  TF_Q103  TF_Q104
# 0       YES     YES      YES      YES      YES      YES      YES
# 1       YES     YES      YES      YES      YES      YES      YES
# 2       YES     YES      YES      YES      YES      YES      YES
# 3       YES     YES      YES      YES      YES      YES      YES
# 4       YES     YES      YES      YES      YES      YES      YES
# ..      ...     ...      ...      ...      ...      ...      ...
# 700     YES     YES      YES      YES      YES      YES      YES
# 701     YES     YES      YES      YES      YES      YES      YES
# 702     YES     YES      YES      YES      YES      YES      YES
# 703     YES     YES      YES      YES      YES      YES      YES
# 704     YES     YES      YES      YES      YES      YES      YES
#
# [705 rows x 192 columns]

# %%
df_nfhs5['statedist'] = df_nfhs5['District']+df_nfhs5['State']

# %%
df_nfhs5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 705 entries, 0 to 704
# Columns: 193 entries, State to statedist
# dtypes: float64(95), object(98)
# memory usage: 1.0+ MB

# %%
districts_new = districts_shp.merge(df_nfhs5, on='statedist')

# %%
districts_new.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 689 entries, 0 to 688
# Columns: 207 entries, objectid to TF_Q104
# dtypes: float64(102), geometry(1), int64(1), object(103)
# memory usage: 1.1+ MB

# %%
list(districts_new.columns)
# Out:
# ['objectid',
#  'statecode',
#  'statename',
#  'state_ut',
#  'distcode',
#  'distname',
#  'distarea',
#  'totalpopul',
#  'totalhh',
#  'totpopmale',
#  'totpopfema',
#  'st_areasha',
#  'st_lengths',
#  'geometry',
#  'statedist',
#  'State',
#  'District',
#  'Q1_NFHS5',
#  'Q2_NFHS5',
#  'Q3_NFHS5',
#  'Q4_NFHS5',
#  'Q5_NFHS5',
#  'Q6_NFHS5',
#  'Q7_NFHS5',
#  'Q8_NFHS5',
#  'Q9_NFHS5',
#  'Q10_NFHS5',
#  'Q11_NFHS5',
#  'Q12_NFHS5',
#  'Q13_NFHS5',
#  'Q14_NFHS5',
#  'Q15_NFHS5',
#  'Q16_NFHS5',
#  'Q17_NFHS5',
#  'Q18_NFHS5',
#  'Q19_NFHS5',
#  'Q20_NFHS5',
#  'Q21_NFHS5',
#  'Q22_NFHS5',
#  'Q23_NFHS5',
#  'Q24_NFHS5',
#  'Q25_NFHS5',
#  'Q26_NFHS5',
#  'Q27_NFHS5',
#  'Q28_NFHS5',
#  'Q29_NFHS5',
#  'Q30_NFHS5',
#  'Q31_NFHS5',
#  'Q32_NFHS5',
#  'Q33_NFHS5',
#  'Q34_NFHS5',
#  'Q35_NFHS5',
#  'Q36_NFHS5',
#  'Q37_NFHS5',
#  'Q38_NFHS5',
#  'Q39_NFHS5',
#  'Q41_NFHS5',
#  'Q42_NFHS5',
#  'Q43_NFHS5',
#  'Q44_NFHS5',
#  'Q45_NFHS5',
#  'Q46_NFHS5',
#  'Q48_NFHS5',
#  'Q49_NFHS5',
#  'Q50_NFHS5',
#  'Q51_NFHS5',
#  'Q52_NFHS5',
#  'Q53_NFHS5',
#  'Q54_NFHS5',
#  'Q55_NFHS5',
#  'Q56_NFHS5',
#  'Q57_NFHS5',
#  'Q58_NFHS5',
#  'Q59_NFHS5',
#  'Q60_NFHS5',
#  'Q61_NFHS5',
#  'Q65_NFHS5',
#  'Q67_NFHS5',
#  'Q70_NFHS5',
#  'Q72_NFHS5',
#  'Q73_NFHS5',
#  'Q74_NFHS5',
#  'Q75_NFHS5',
#  'Q76_NFHS5',
#  'Q77_NFHS5',
#  'Q78_NFHS5',
#  'Q79_NFHS5',
#  'Q80_NFHS5',
#  'Q81_NFHS5',
#  'Q82_NFHS5',
#  'Q83_NFHS5',
#  'Q84_NFHS5',
#  'Q85_NFHS5',
#  'Q86_NFHS5',
#  'Q87_NFHS5',
#  'Q88_NFHS5',
#  'Q89_NFHS5',
#  'Q90_NFHS5',
#  'Q91_NFHS5',
#  'Q92_NFHS5',
#  'Q93_NFHS5',
#  'Q94_NFHS5',
#  'Q95_NFHS5',
#  'Q96_NFHS5',
#  'Q97_NFHS5',
#  'Q98_NFHS5',
#  'Q99_NFHS5',
#  'Q100_NFHS5',
#  'Q101_NFHS5',
#  'Q102_NFHS5',
#  'Q103_NFHS5',
#  'Q104_NFHS5',
#  'TF_Q1',
#  'TF_Q2',
#  'TF_Q3',
#  'TF_Q4',
#  'TF_Q5',
#  'TF_Q6',
#  'TF_Q7',
#  'TF_Q8',
#  'TF_Q9',
#  'TF_Q10',
#  'TF_Q11',
#  'TF_Q12',
#  'TF_Q13',
#  'TF_Q14',
#  'TF_Q15',
#  'TF_Q16',
#  'TF_Q17',
#  'TF_Q18',
#  'TF_Q19',
#  'TF_Q20',
#  'TF_Q21',
#  'TF_Q22',
#  'TF_Q23',
#  'TF_Q24',
#  'TF_Q25',
#  'TF_Q26',
#  'TF_Q27',
#  'TF_Q28',
#  'TF_Q29',
#  'TF_Q30',
#  'TF_Q31',
#  'TF_Q32',
#  'TF_Q33',
#  'TF_Q34',
#  'TF_Q35',
#  'TF_Q36',
#  'TF_Q37',
#  'TF_Q38',
#  'TF_Q39',
#  'TF_Q41',
#  'TF_Q42',
#  'TF_Q43',
#  'TF_Q44',
#  'TF_Q45',
#  'TF_Q46',
#  'TF_Q48',
#  'TF_Q49',
#  'TF_Q50',
#  'TF_Q51',
#  'TF_Q52',
#  'TF_Q53',
#  'TF_Q54',
#  'TF_Q55',
#  'TF_Q56',
#  'TF_Q57',
#  'TF_Q58',
#  'TF_Q59',
#  'TF_Q60',
#  'TF_Q61',
#  'TF_Q65',
#  'TF_Q67',
#  'TF_Q70',
#  'TF_Q72',
#  'TF_Q73',
#  'TF_Q74',
#  'TF_Q75',
#  'TF_Q76',
#  'TF_Q77',
#  'TF_Q78',
#  'TF_Q79',
#  'TF_Q80',
#  'TF_Q81',
#  'TF_Q82',
#  'TF_Q83',
#  'TF_Q84',
#  'TF_Q85',
#  'TF_Q86',
#  'TF_Q87',
#  'TF_Q88',
#  'TF_Q89',
#  'TF_Q90',
#  'TF_Q91',
#  'TF_Q92',
#  'TF_Q93',
#  'TF_Q94',
#  'TF_Q95',
#  'TF_Q96',
#  'TF_Q97',
#  'TF_Q98',
#  'TF_Q99',
#  'TF_Q100',
#  'TF_Q101',
#  'TF_Q102',
#  'TF_Q103',
#  'TF_Q104']

# %%
for i in range(districts_new.shape[0]):
    if districts_new.iloc[i]['statename'] != districts_new.iloc[i]['State'] or \
       districts_new.iloc[i]['distname'] != districts_new.iloc[i]['District']:
        print(i, 'District mismatched!')

# %%
print('Districts in NFHS-5 that are not listed in the shapefile:')
count = 1
for i in range(df_nfhs5.shape[0]):
    if df_nfhs5.iloc[i]['statedist'] not in list(districts_shp['statedist']):
        print(f"{count:>3} {df_nfhs5.iloc[i]['State']:>18} {df_nfhs5.iloc[i]['District']:>25}")
        count += 1
# Out:
# Districts in NFHS-5 that are not listed in the shapefile:
#   1  Arunachal_Pradesh                 Kra Daadi
#   2  Arunachal_Pradesh                  Longding
#   3  Arunachal_Pradesh                    Namsai
#   4  Arunachal_Pradesh                     Siang
#   5              Assam                 Biswanath
#   6              Assam                 Charaideo
#   7              Assam                     Hojai
#   8              Assam                    Majuli
#   9              Assam   South Salmara Mancachar
#  10              Assam        West Karbi Anglong
#  11            Haryana             Charkhi Dadri
#  12     Madhya_Pradesh                Agar Malwa
#  13        West_Bengal        Paschim Barddhaman
#  14        West_Bengal          Purba Barddhaman
#  15          NCT_Delhi                  Shahdara
#  16          NCT_Delhi                South East

# %%
print('Districts in the shapefile that are not listed in NFHS-5:')
count = 1
for i in range(districts_shp.shape[0]):
    if districts_shp.iloc[i]['statedist'] not in list(df_nfhs5['statedist']):
        print(f"{count:>3} {districts_shp.iloc[i]['statename']:>18} {districts_shp.iloc[i]['distname']:>25}")
        count += 1
# Out:
# Districts in the shapefile that are not listed in NFHS-5:
#   1      Jammu_Kashmir        DATA NOT AVAILABLE
#   2        Lakshadweep               Lakshadweep
#   3        West_Bengal                Barddhaman
#   4         Chandigarh                Chandigarh

# %% [markdown]
# Write Merged DF To Shapefile
# ----

# %%
districts_new.to_file("../DATA/NFHS5_districts.shp")
