# %%
import pickle

# %%
questions = { # Population and Household Profile 
              1:   'Female population age 6 years and above who attended school (%)',
              2:   'Population below age 15 years(%)',       
              3:   'Sex ratio of the total population (females per 1,000 males)',
              4:   'Sex ratio at birth for children born in the last five years (females per 1,000 males)',
              5:   'Children under age 5 years whose birth was registered with the civil authority (%)',
              6:   'Deaths in the last 3 years registered with the civil authority (%)',
              7:   'Population living in households with electricity (%)',       
              8:   'Population living in households with an improved drinking-water source (%)',
              9:   'Population living in households that use an improved sanitation facility (%)',
             10:   'Households using clean fuel for cooking (%)',
             11:   'Households using iodizedsalt (%)',                         
             12:   'Households with any usual member covered under a health insurance/financing scheme (%)',
             13:   'Children age 5 years who attended pre-primary school during the school year 2019-20 (%)',
             # Characteristics of Women (age 15-49 years)
             14:   'Women age 15-49 years who are literate (%)',
             15:   'Women age 15-49 years with 10 or more years of schooling (%)', 
             #  Marriage and Fertility
             16:   'Women age 20-24 years married before age 18 years (%)',
             17:   'Births in the 5 years preceding the survey that are third or higher order(%)',
             18:   'Women age 15-19 years who were already mothers or pregnant at the time of the survey (%)',
             19:   'Women age 15-24 years who use hygienic methods of protection during their menstrual period (%)',
             # Current Use of Family Planning Methods (currently married women age 15–49 years)
             20:   'Among currently married women age 15–49 years, current use of any family planning method (%)',
             21:   'Among currently married women age 15–49 years, current use of any modern family planning method (%)',
             22:   'Among currently married women age 15–49 years, current use of Female sterilization (%)', 
             23:   'Among currently married women age 15–49 years, current use of Male sterilization(%)',                                                    
             24:   'Among currently married women age 15–49 years, current use of IUD/PPIUD (%)',                                                        
             25:   'Among currently married women age 15–49 years, current use of Pill (%)',                                                    
             26:   'Among currently married women age 15–49 years, current use of Condom (%)',
             27:   'Among currently married women age 15–49 years, current use of Injectables (%)',
             # Unmet Need for Family Planning (currently married women age 15–49 years)
             28:   'Total unmet need (%)',
             29:   'Unmet need for spacing (%)',
             # Quality of Family Planning Services
             30:   'Health worker ever talked to female non-users about family planning (%)', 
             31:   'Current users ever told about side effects of current method (%)',                
             # Maternal and Child Health 
             # Maternity Care (for last birth in the 5 years before the survey)
             32:   'Mothers who had an antenatal check-up in the first trimester (%)',
             33:   'Mothers who had at least 4 antenatal care visits (%)',
             34:   'Mothers whose last birth was protected against neonatal tetanus (%)',
             35:   'Mothers who consumed iron folic acid for 100 days or more when they were pregnant (%)',
             36:   'Mothers who consumed iron folic acid for 180 days or more when they were pregnant (%)',
             37:   'Registered pregnancies for which the mother received a Mother and Child Protection(MCP) card (%)',
             38:   'Mothers who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)',
             39:   'Average out-of-pocket expenditure per delivery in a public health facility (Rs.)',
             40:   'Children born at home who were taken to a health facility for a check-up within 24 hours of birth (%)',
             41:   'Children who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)',
             # Delivery Care (for births in the 5 years before the survey)
             42:   'Among births in the 5 years before the survey, institutional births (%)',
             43:   'Among births in the 5 years before the survey, institutional births in public facility (%)',
             44:   'Among births in the 5 years before the survey, home births that were conducted by skilled health personnel (%)',
             45:   'Among births in the 5 years before the survey, births attended by skilled health personnel (%)',
             46:   'Among births in the 5 years before the survey, births delivered by caesarean section (%)',
             47:   'Among births in the 5 years before the survey, births in a private health facility that were delivered by caesarean section (%)',
             48:   'Among births in the 5 years before the survey, births in a public health facility that were delivered by caesarean section (%)',
             # Child Vaccinations and Vitamin A Supplementation
             49:   "Children age 12-23 months fully vaccinated based on information from either vaccination card or mother's recall (%)",
             50:   'Children age 12-23 months fully vaccinated based on information from vaccination card only (%)',
             51:   'Children age 12-23 months who have received BCG(%)',
             52:   'Children age 12-23 months who have received 3 doses of polio vaccine (%)',
             53:   'Children age 12-23 months who have received 3 doses of penta or DPT vaccine (%)',
             54:   'Children age 12-23 months who have received the first dose of measles-containing vaccine(MCV) (%)',
             55:   'Children age 24-35 months who have received a second dose of measles-containing vaccine(MCV) (%)',
             56:   'Children age 12-23 months who have received 3 doses of rotavirus vaccine (%)',
             57:   'Children age 12-23 months who have received 3 doses of penta or hepatitis B vaccine (%)',
             58:   'Children age 9-35 months who received a vitamin A dose in the last 6 months (%)',
             59:   'Children age 12-23 months who received most of their vaccinations in a public health facility (%)',
             60:   'Children age 12-23 months who received most of their vaccinations in a private health facility (%)',
             # Treatment of Childhood Diseases (children under age 5 years)
             61:   'Children under age 5 years with prevalence of diarrhoea in the 2 weeks preceding the survey (%)',
             62:   'Children under age 5 years with diarrhoea in the 2 weeks preceding the survey who received oral rehydration salts(ORS) (%)',
             63:   'Children under age 5 years with diarrhoea in the 2 weeks preceding the survey who received zinc (%)',
             64:   'Children under age 5 years with diarrhoea in the 2 weeks preceding the survey taken to a health facility or health provider (%)',
             65:   'Children under age 5 years with prevalence of symptoms of acute respiratory infection(ARI) in the 2 weeks preceding the survey(%)',
             66:   'Children under age 5 years with fever or symptoms of ARI in the 2 weeks preceding the survey taken to a health facility or health provider (%)',
             # Child Feeding Practices and Nutritional Status of Children
             67:   'Children under age 3 years breast fed within one hour of birth (%)',
             68:   'Children under age 6 months exclusively breastfed (%)',
             69:   'Children age 6-8 months receiving solid or semi-solid food and breastmilk (%)',
             70:   'Breast feeding children age 6-23 months receiving an adequate diet (%)',
             71:   'Non-breast feeding children age 6-23 months receiving an adequate diet (%)',
             72:   'Total children age 6-23 months receiving an adequate diet (%)',
             73:   'Children under 5 years who are stunted (height-for-age) (%)',
             74:   'Children under 5 years who are wasted (weight-for-height) (%)',
             75:   'Children under 5 years who are severely wasted(weight-for-height) (%)',
             76:   'Children under 5 years who are underweight (weight-for-age) (%)',
             77:   'Children under 5 years who are overweight (weight-for-height) (%)',
             # Nutritional Status of Women (age 15-49 years)
             78:   'Women age 15-49 years whose Body Mass Index(BMI) is below normal (BMI<18.5kg/m2) (%)',
             79:   'Women age 15-49 years who are over weight or obese (BMI≥25.0kg/m2) (%)',
             80:   'Women age 15-49 years who have high risk waist-to-hip ratio (≥0.85) (%)',
             # Anaemia among Children and Women
             81:   'Children age 6-59 months who are anaemic (<11.0g/dl) (%)',
             82:   'Non-pregnant women age 15-49 years who are anaemic (<12.0g/dl) (%)',
             83:   'Pregnant women age 15-49 years who are anaemic (<11.0g/dl) (%)',
             84:   'All women age 15-49 years who are anaemic (%)',
             85:   'All women age 15-19 years who are anaemic (%)',
             # Blood Sugar Level among Adults (age 15 years and above)
             # Women
             86:   "Blood sugar level - high (141-160 mg/dl) among women age 15 and above (%)",
             87:   "Blood sugar level - very high (>160 mg/dl) among women age 15 and above (%)",
             88:   "Blood sugar level - high or very high (>140 mg/dl) or taking medicine to control blood sugar level among women age 15 and above (%)",
             # Men
             89:   "Blood sugar level - high (141-160 mg/dl) among men age 15 and above (%) ",
             90:   "Blood sugar level - very high (>160 mg/dl) among men age 15 and above (%)",
             91:   "Blood sugar level - high or very high (>140 mg/dl) or taking medicine to control blood sugar level among men age 15 and above (%)",
             # Hypertension among Adults (age 15 years and above)
             # Women 
             92:   "Mildly elevated blood pressure (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) among women age 15 and above (%)",
             93:   "Moderately or severely elevated blood pressure (Systolic ≥160mm of Hg and/or Diastolic ≥100mm of Hg) among women age 15 and above (%)",
             94:   "Elevated blood pressure (Systolic ≥140 mm of Hg and/or Diastolic ≥90 mm of Hg) or taking medicine to control blood pressure among women age 15 and above (%)",
             # Men 
             95:   "Mildly elevated blood pressure (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) among men age 15 and above (%)",
             96:   "Moderately or severely elevated blood pressure (Systolic ≥160mm of Hg and/or Diastolic ≥100mm of Hg) among men age 15 and above (%)",
             97:   "Elevated blood pressure (Systolic ≥140 mm of Hg and/or Diastolic ≥90 mm of Hg) or taking medicine to control blood pressure among men age 15 and above (%)",
             # Screening for Cancer among Women (age 30-49 years)
             98:   "Women age 30-49 years who have ever undergone a screening test for cervical cancer (%)",
             99:   "Women age 30-49 years who have ever undergone a breast examination for breast cancer (%)", 
             100:  "Women age 30-49 years who have ever undergone an oral cavity examination for oral cancer (%)",
             # Tobacco Use and Alcohol Consumption among Adults (age 15 years and above)
             101:  "Women age 15 years and above who use any kind of tobacco (%)",
             102:  "Men age 15 years and above who use any kind of tobacco (%)",
             103:  "Women age 15 years and above who consume alcohol (%)",
             104:  "Men age 15 years and above who consume alcohol (%)"
            }

# %%
# For Question --> True  : use cmap = 'YlGn'
#     Question --> False : use cmap = 'YlOrBr'
is_bigger_greener = { # Population and Household Profile 
              1:   True,
              2:   True,       
              3:   True,
              4:   True,
              5:   True,
              6:   False,
              7:   True,       
              8:   True,
              9:   True,
             10:   True,
             11:   True,                         
             12:   True,
             13:   True,
             # Characteristics of Women (age 15-49 years)
             14:   True,
             15:   True, 
             #  Marriage and Fertility
             16:   False,
             17:   False,
             18:   False,
             19:   True,
             # Current Use of Family Planning Methods (currently married women age 15–49 years)
             20:   True,
             21:   True,
             22:   True, 
             23:   True,
             24:   True,
             25:   True,
             26:   True,
             27:   True, 
             # Unmet Need for Family Planning (currently married women age 15–49 years)
             28:   False,
             29:   False,
             # Quality of Family Planning Services
             30:   True,
             31:   True,
             # Maternal and Child Health 
             # Maternity Care (for last birth in the 5 years before the survey)
             32:   True,
             33:   True,
             34:   True,
             35:   True,
             36:   True,
             37:   True,
             38:   True,
             39:   False,
             40:   True,
             41:   True,
             # Delivery Care (for births in the 5 years before the survey)
             42:   True,
             43:   True,
             44:   True,
             45:   True,
             46:   True,
             47:   True,
             48:   True,
             # Child Vaccinations and Vitamin A Supplementation
             49:   True,
             50:   True,
             51:   True,
             52:   True,
             53:   True,
             54:   True,
             55:   True,
             56:   True,
             57:   True,
             58:   True,
             59:   True,
             60:   True,
             # Treatment of Childhood Diseases (children under age 5 years)
             61:   False,
             62:   True,
             63:   True,
             64:   True,
             65:   False,
             66:   True,
             # Child Feeding Practices and Nutritional Status of Children
             67:   True,
             68:   True,
             69:   True,
             70:   True,
             71:   True,
             72:   True,
             73:   False,
             74:   False,
             75:   False,
             76:   False,
             77:   False,
             # Nutritional Status of Women (age 15-49 years)
             78:   False,
             79:   False,
             80:   False,
             # Anaemia among Children and Women
             81:   False,
             82:   False,
             83:   False,
             84:   False,
             85:   False,
             # Blood Sugar Level among Adults (age 15 years and above)
             # Women
             86:   False,
             87:   False,
             88:   False,
             # Men
             89:   False,
             90:   False,
             91:   False,
             # Hypertension among Adults (age 15 years and above)
             # Women 
             92:   False,
             93:   False,
             94:   False,
             # Men 
             95:   False,
             96:   False,
             97:   False,
             # Screening for Cancer among Women (age 30-49 years)
             98:   True,
             99:   True,
             100:  True,
             # Tobacco Use and Alcohol Consumption among Adults (age 15 years and above)
             101:  False,
             102:  False,
             103:  False,
             104:  False
            }

# %%
with open('../DATA/questions.pickle', 'wb') as f:
    # Pickle the 'questions' list using the highest protocol available.
    pickle.dump(questions, f, pickle.HIGHEST_PROTOCOL)

# %%
with open('../DATA/is_bigger_greener.pickle', 'wb') as f:
    # Pickle the 'questions' list using the highest protocol available.
    pickle.dump(is_bigger_greener, f, pickle.HIGHEST_PROTOCOL)
